# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
# Listing of Variables used in the report
totalplayercount = purchase_data["SN"].nunique()
totalpurchasecount = purchase_data["Purchase ID"].nunique()

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
# Createa a new Data Frame for Unique Players
unique_players_count_df = pd.DataFrame(
    {"Total Players": [totalplayercount]
    }
)

unique_players_count_df
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Create a new Data Frame and get the data
purchase_data_analysis = pd.DataFrame(
    {"Number of Unique Items": [purchase_data['Item Name'].nunique()],
     "Average Price": [purchase_data['Price'].mean()],
     "Number of Purhases": [purchase_data['Purchase ID'].nunique()],
     "Total Revenue": [purchase_data['Price'].sum()]
     }
)

# Clean up the formatting
purchase_data_analysis["Average Price"] = purchase_data_analysis["Average Price"].astype(float).map("${:,.2f}".format)
purchase_data_analysis["Total Revenue"] = purchase_data_analysis["Total Revenue"].astype(float).map("${:,.2f}".format)

purchase_data_analysis
# Out:
#    Number of Unique Items Average Price  Number of Purhases Total Revenue
# 0                     179         $3.05                 780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
# Get the data and create calculations
gender_demographics_df = purchase_data
gender_demographics_df = gender_demographics_df.drop_duplicates(subset="SN", keep='first')
gender_demographics_df = gender_demographics_df['Gender'].value_counts()
uniquepersongender = gender_demographics_df

# Calculate the Percentage of players for each gender (total players = unique count of players)
percentage_df = gender_demographics_df / totalplayercount

# Create a new dataframe to display the results 
display_df = pd.DataFrame(
    {"Total Count": gender_demographics_df,
     "Percentage of Players": percentage_df
    }
)    

# Clean up the formatting
display_df["Percentage of Players"] = display_df["Percentage of Players"].astype(float).map("{:,.2%}".format)

# Display DF 
display_df
# Out:
#                        Total Count Percentage of Players
# Male                           484                84.03%
# Female                          81                14.06%
# Other / Non-Disclosed           11                 1.91%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Get the data and create calculations
gender_demographics_df = purchase_data
gender_demographics_df = gender_demographics_df['Gender'].value_counts()

# Calculate the Count of Sales, Average Price and Total 
sumprice = purchase_data.groupby(["Gender"]).sum()["Price"]
meanprice = purchase_data.groupby(["Gender"]).mean()["Price"]
countsale = purchase_data.groupby(["Gender"]).count()["Price"]
countsale = purchase_data.groupby(["Gender"]).nunique()["Price"]
averagesaleperson = sumprice / uniquepersongender

# Create a new dataframe to display the results 
display_df1 = pd.DataFrame(
    {"Purchase Count": gender_demographics_df,
     "Average Purchase Price": meanprice,
     "Total Purchase Value": sumprice,
     "Avg Total Purchase per Person": averagesaleperson,
    }
)   

# Clean up the formatting
display_df1 = display_df1.sort_index(axis=0, level=None, ascending=True)
display_df1["Average Purchase Price"] = display_df1["Average Purchase Price"].astype(float).map("${:,.2f}".format)
display_df1["Total Purchase Value"] = display_df1["Total Purchase Value"].astype(float).map("${:,.2f}".format)
display_df1["Avg Total Purchase per Person"] = display_df1["Avg Total Purchase per Person"].astype(float).map("${:,.2f}".format)

# Display DF
display_df1
# Out:
#                        Purchase Count Average Purchase Price  \
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Get the data
age_bin = purchase_data[["Age", "SN"]]

# Remove the duplicate screen name values
age_bin = age_bin.drop_duplicates(subset="SN", keep='first')

# Create the bins and bin labels in which Data will be held
bins = [0, 9.99, 14.99, 19.99, 24.99, 29.99, 34.99, 39.99, 999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# Cut the details into the relevant bins
age_bin["Age Summary"] = pd.cut(purchase_data['Age'], bins, labels=group_names, include_lowest=True)

# Create a new column to store the age range values
age_ranges = age_bin["Age Summary"].value_counts()

# Calculate the Percentage of players for each gender (total players = unique count of players)
age_percentage = age_ranges / totalplayercount

# Create a new dataframe to display the results 
display_df2 = pd.DataFrame(
    {"Total Count": age_ranges,
     "Percentage of Players": age_percentage
    }
)

# Clean up the formatting (including sort order)
display_df2 = display_df2.sort_index(axis=0, level=None, ascending=True)
display_df2["Percentage of Players"] = display_df2["Percentage of Players"].astype(float).map("{:,.2%}".format)

# Display DF
display_df2
# Out:
#        Total Count Percentage of Players
# <10             17                 2.95%
# 10-14           22                 3.82%
# 15-19          107                18.58%
# 20-24          258                44.79%
# 25-29           77                13.37%
# 30-34           52                 9.03%
# 35-39           31                 5.38%
# 40+             12                 2.08%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Get the data
age_bin = purchase_data
age_bin

# Create the bins and bin labels in which Data will be held
bins = [0, 9.99, 14.99, 19.99, 24.99, 29.99, 34.99, 39.99, 999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# Cut the details into the relevant bins
age_bin["Age Summary"] = pd.cut(purchase_data['Age'], bins, labels=group_names, include_lowest=True)

# Create a new column to store the age range values
age_ranges = age_bin["Age Summary"].value_counts()

# Calculate the Count of Sales, Average Price and Total 
sumprice = age_bin.groupby(["Age Summary"]).sum()["Price"]
meanprice = age_bin.groupby(["Age Summary"]).mean()["Price"]
countsale = age_bin.groupby(["Age Summary"]).count()["Price"]
averagesaleperson = sumprice / display_df2["Total Count"]

# Create a new dataframe to display the results 
display_df3 = pd.DataFrame(
    {"Age Ranges": age_ranges,
     "Purchase Count": countsale,
     "Average Purchase Price": meanprice,
     "Total Purchase Value": sumprice,
     "Avg Total Purchase per Person": averagesaleperson,
    }
)

# Clean up the formatting (including sort order)
display_df3 = display_df3.sort_index(axis=0, level=None, ascending=True)
display_df3["Average Purchase Price"] = display_df3["Average Purchase Price"].astype(float).map("${:,.2f}".format)
display_df3["Total Purchase Value"] = display_df3["Total Purchase Value"].astype(float).map("${:,.2f}".format)
display_df3["Avg Total Purchase per Person"] = display_df3["Avg Total Purchase per Person"].astype(float).map("${:,.2f}".format)

# Display DF
display_df3
# Out:
#        Age Ranges  Purchase Count Average Purchase Price Total Purchase Value  \
# <10            23              23                  $3.35               $77.13
# 10-14          28              28                  $2.96               $82.78
# 15-19         136             136                  $3.04              $412.89
# 20-24         365             365                  $3.05            $1,114.06
# 25-29         101             101                  $2.90              $293.00
# 30-34          73              73                  $2.93              $214.00
# 35-39          41              41                  $3.60              $147.67
# 40+            13              13                  $2.94               $38.24
#
#       Avg Total Purchase per Person
# <10                           $4.54
# 10-14                         $3.76
# 15-19                         $3.86
# 20-24                         $4.32
# 25-29                         $3.81
# 30-34                         $4.12
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Calculate the Count of Sales, Average Price and Total 
sumprice = age_bin.groupby(["SN"]).sum()["Price"]
meanprice = age_bin.groupby(["SN"]).mean()["Price"]
countsale = age_bin.groupby(["SN"]).count()["Price"]
averagesaleperson = sumprice / countsale

# Create a new dataframe to display the results 
display_df4 = pd.DataFrame(
    {"Purchase Count": countsale,
     "Average Purchase Price": meanprice,
     "Total Purchase Value": sumprice,
    }
)

# Clean up the formatting (including sort order)
display_df4 = display_df4.sort_values(["Total Purchase Value"], ascending=False)

display_df4["Average Purchase Price"] = display_df4["Average Purchase Price"].astype(float).map("${:,.2f}".format)
display_df4["Total Purchase Value"] = display_df4["Total Purchase Value"].astype(float).map("${:,.2f}".format)

# Display DF
display_df4.head(5)
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
popular_items_df = purchase_data[["Item ID", "Item Name", "Price"]]
popular_items_df = popular_items_df.groupby(["Item ID","Item Name"])

# Calculate the Count of Sales, Average Price and Total
sumprice = popular_items_df["Price"].sum()
sumcount = popular_items_df["Price"].count()
itemprice = sumprice / sumcount

# Create a new dataframe to display the results 
display_df5 = pd.DataFrame(
    {"Purchase Count": sumcount,
     "Item Price": itemprice,
     "Total Purchase Value": sumprice
    }
)

# Clean up the formatting (including sort order of "Purchase Count")
display_df5 = display_df5.sort_values(["Purchase Count"], ascending=False)

display_df5["Purchase Count"] = display_df5["Purchase Count"].astype(float).map("{:,.0f}".format)
display_df5["Item Price"] = display_df5["Item Price"].astype(float).map("${:,.2f}".format)
display_df5["Total Purchase Value"] = display_df5["Total Purchase Value"].astype(float).map("${:,.2f}".format)

display_df5.head(5)
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 132     Persuasion                                                9
# 108     Extraction, Quickblade Of Trembling Hands                 9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 132     Persuasion                                        $3.22
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Create a new dataframe to display the results 
display_df6 = pd.DataFrame(
    {"Purchase Count": sumcount,
     "Item Price": itemprice,
     "Total Purchase Value": sumprice
    }
)

# Clean up the formatting (including changing the sort order to "Total Purchase Value")
display_df6 = display_df6.sort_values(["Total Purchase Value"], ascending=False)

display_df6["Purchase Count"] = display_df6["Purchase Count"].astype(float).map("{:,.0f}".format)
display_df6["Item Price"] = display_df6["Item Price"].astype(float).map("${:,.2f}".format)
display_df6["Total Purchase Value"] = display_df6["Total Purchase Value"].astype(float).map("${:,.2f}".format)

display_df6.head(5)
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...
